# %% [markdown]
# 1. 데이터 읽어오기 (1)
# [문제 1]
# 판다스의 read_csv() 함수를 사용해서 train.csv 파일을 읽어와봅시다!

# %%
import pandas as pd

train = pd.read_csv('train.csv')

# %% [markdown]
# 2. 데이터 읽어오기 (2)
# [문제 2]
# 빈칸을 채워서 예측할 데이터 파일(test.csv) 및 제출할 파일(sample_submission.csv)을 읽어와 주세요.

# %%
test = pd.read_csv('test.csv')
submission = pd.read_csv('sample_submission.csv')

# %% [markdown]
# 3. 상위 3개 행(row) 데이터 확인하기
# [문제 3]
# head() 메서드를 사용해서 train 데이터의 상위 3개 행(row) 데이터를 확인해봅시다!

# %%
train.head(3)

# %% [markdown]
# 4. 하위 3개 행(row) 데이터 확인하기
# [문제 4]
# tail() 메서드를 사용해서 train 데이터의 하위 3개 행(row)의 데이터를 확인해봅시다!

# %%
train.tail(3)

# %% [markdown]
# 5. 제출 파일 확인하기¶
# [문제 5]
# 빈칸을 채워 위에서 읽어왔던 submission 데이터의 상위 4개 행(row)을 확인해 보세요.

# %%
submission.head(4)

# %% [markdown]
# 6. csv파일 저장
# [문제 6]
# to_csv() 메서드를 사용해서 submission 데이터프레임을 csv 파일로 저장해봅시다!

# %%
# 매개변수는 수정하지 말아주세요.
submission.to_csv('submission.csv', index=False, quoting=2, encoding="utf-8-sig", na_rep=0, float_format='%.6f')
